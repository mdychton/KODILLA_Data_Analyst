# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'e1': [80, 85, 90],
    'e2': [75, 88, 92]
}, index=['Student A', 'Student B', 'Student C'])

df.loc['Student B']
# Out:
# e1    85
# e2    88
# Name: Student B, dtype: int64

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92

# %%
df.loc['Student X'] = [90,1]

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92
# Student X  90   1

# %%
import pandas as pd

left = pd.DataFrame({
    'user_id': [1, 2, 3],
    'name': ['Adam', 'Ewa', 'Jan']
})

right = pd.DataFrame({
    'user_id': [1, 2, 4],
    'score': [100, 200, 300]
})

# %%
left
right
# Out:
#    user_id  score
# 0        1    100
# 1        2    200
# 2        4    300

# %%
right
# Out:
#   category_name
# 1          food
# 2          tech
# 3       clothes

# %%
left
# Out:
#    user_id  name
# 0        1  Adam
# 1        2   Ewa
# 2        3   Jan

# %%
#pd.merge(left,right,how="inner",on='key')  #innerJoin

# %%
left.merge(right, on='user_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 left.merge(right, on='user_id', how='left')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:12888, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   12884         self._check_copy_deprecation(copy)
#   12885
#   12886         from pandas.core.reshape.merge import merge
#   12887
# > 12888         return merge(
#   12889             self,
#   12890             right,
#   12891             how=how,
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1018, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1008     raise MergeError(msg)
#    1010 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#    1012 (
#    1013     self.left_join_keys,
#    1014     self.right_join_keys,
#    1015     self.join_names,
#    1016     left_drop,
#    1017     right_drop,
# -> 1018 ) = self._get_merge_keys()
#    1020 if left_drop:
#    1021     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:1620, in _MergeOperation._get_merge_keys(self)
#    1618 rk = cast(Hashable, rk)
#    1619 if rk is not None:
# -> 1620     right_keys.append(right._get_label_or_level_values(rk))
#    1621 else:
#    1622     # work-around for merge_asof(right_index=True)
#    1623     right_keys.append(right.index._values)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'user_id'

# %%
active_users
# Out:
#    user_id
# 0       10
# 1       30

# %%
orders.merge(active_users[['user_id']], on='user_id')
# Out:
#    order_id  user_id
# 0         1       10
# 1         3       30

# %%
left = pd.DataFrame({
    'product': ['A','B','C'],
    'category_id': [1,2,3]
})

right = pd.DataFrame({
    'category_name': ['food','tech','clothes']
}, index=[1,2,3])

# %%
left
# Out:
#   product  category_id
# 0       A            1
# 1       B            2
# 2       C            3

# %%
right
# Out:
#   category_name
# 1          food
# 2          tech
# 3       clothes

# %%
left.join(right,on='category_id')
# Out:
#   product  category_id category_name
# 0       A            1          food
# 1       B            2          tech
# 2       C            3       clothes
