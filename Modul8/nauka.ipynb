# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'e1': [80, 85, 90],
    'e2': [75, 88, 92]
}, index=['Student A', 'Student B', 'Student C'])

df.loc['Student B']
# Out:
# e1    85
# e2    88
# Name: Student B, dtype: int64

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92

# %%
df.loc['Student X'] = [90,1]

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92
# Student X  90   1

# %%
import pandas as pd

left = pd.DataFrame({
    'user_id': [1, 2, 3],
    'name': ['Adam', 'Ewa', 'Jan']
})

right = pd.DataFrame({
    'user_id': [1, 2, 4],
    'score': [100, 200, 300]
})

# %%
left
right
# Out:
#    user_id  score
# 0        1    100
# 1        2    200
# 2        4    300

# %%
right
# Out:
#    user_id  score
# 0        1    100
# 1        2    200
# 2        4    300

# %%
left
# Out:
#    user_id  name
# 0        1  Adam
# 1        2   Ewa
# 2        3   Jan

# %%
#pd.merge(left,right,how="inner",on='key')  #innerJoin

# %%
left.merge(right, on='user_id', how='left')
# Out:
#    user_id  name  score
# 0        1  Adam  100.0
# 1        2   Ewa  200.0
# 2        3   Jan    NaN

# %%
active_users
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 active_users
#
# NameError: name 'active_users' is not defined

# %%
orders.merge(active_users[['user_id']], on='user_id')

# %%
left = pd.DataFrame({
    'product': ['A','B','C'],
    'category_id': [1,2,3]
})

right = pd.DataFrame({
    'category_name': ['food','tech','clothes']
}, index=[1,2,3])

# %%
left

# %%
right

# %%
left.join(right,on='category_id')

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel('Pivot.xlsx')

# %%
df.head()

# %%
def poziom_sprzedazy(x):
    if x < 300:
        return 'niska'
    elif x > 900:
        return 'wysoka'
    else:
        return 'srednia'

# %%
df['Poziom_sprzedazy'] = df['Sprzedaż'].apply(lambda x: poziom_sprzedazy(x))

# %%
df

# %%
#zadanie 2

# %%
df['Product_upper'] = df.Produkt.apply.upper()

# %%
import math

# %%
def rabat(x):

    if x > 1000:
        return x *0.1
    else:
        return x *0.05

# %%
df['Rabat'] = df['Sprzedaż'].apply(lambda x: rabat(x))

# %%
df

# %%
df['Produkt_clean'] = df['Produkt'].str.strip().str.lower()

# %%
df

# %%
df['Marża_%'] = ((df['Sprzedaż'] - df['Koszty']) / df['Sprzedaż']).round(2)

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92
# Student X  90   1

# %%
def ocena(row):
    # liczymy marżę dla wiersza
    marza = (row['Sprzedaż'] - row['Koszty']) / row['Sprzedaż']
    
    # klasyfikacja
    if marza > 0.5:
        return 'TOP'
    elif marza >= 0.2:
        return 'OK'
    else:
        return 'LOW'

# axis=1 → działamy na wierszach
df['Ocena'] = df.apply(ocena, axis=1)

# %%
RegionKraj_dict ={
    'East':'Poland',
    'West': 'Germany',
    'North':'Sweden'
}

# %%
df['Region_Kraj'] =df['Region'].map(RegioKraj_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df
