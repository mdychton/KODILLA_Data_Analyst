# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'e1': [80, 85, 90],
    'e2': [75, 88, 92]
}, index=['Student A', 'Student B', 'Student C'])

df.loc['Student B']
# Out:
# e1    85
# e2    88
# Name: Student B, dtype: int64

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92

# %%
df.loc['Student X'] = [90,1]

# %%
df
# Out:
#            e1  e2
# Student A  80  75
# Student B  85  88
# Student C  90  92
# Student X  90   1
